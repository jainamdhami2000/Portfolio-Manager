# %%
import numpy as np
import pandas as pd

# %%
dataset1 = pd.read_csv('mrg_trading.csv',error_bad_lines=False,encoding='latin')
dataset1.to_csv('mrg_trading.csv', encoding='utf-8')
dataset2 = pd.read_csv('mrg_trading.csv')
dataset2
# Out:
#      Unnamed: 0                                       Unnamed: 0.1  \
# 0             0                                                NaN
# 1             1  ÃÂ+ÃÂ ÃÂ
# ÃÂ¯@ÃÂ'ÃÂÃÂºohÃÂ¡MÃÂÃ...
# 2             2  ÃÂ¯-ÃÂ´]t#-KÃÂÃÂ¬ÃÂ%&ÃÂh|#pÃÂ·ÃÂ¡Ã...
# 3             3                                     |IÃÂSakÃÂ´
# 4             4  $ÃÂ.ZÃÂ©iÃÂ¶ÃÂÃÂÃÂ~ÃÂ6ÃÂ´ÃÂ¨ÃÂ...
# ..          ...                                                ...
# 285         285                                                NaN
# 286         286                                                NaN
# 287         287                                                NaN
# 288         288                                                NaN
# 289         289                                                NaN
#
#                                       PK
# 0    ÃÂ­ÃÂSoÃÂ®jp$ÃÂ¦ÃÂ£ÃÂ±ÃÂÃÂ
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 285                                    NaN
# 286                                    NaN
# 287                                    NaN
# 288
# 289                                    NaN
#
# [290 rows x 3 columns]

# %%
dataset2 = pd.read_csv('q.csv')

# %%
dataset2
# Out:
#    INSTRUMENT TYPE \n  SYMBOL \n EXPIRY DATE \n OPTION TYPE \n  \
# 0       Index Options  BANKNIFTY    24-Sep-2020            Put
# 1       Index Options  BANKNIFTY    24-Sep-2020           Call
# 2       Index Options      NIFTY    24-Sep-2020            Put
# 3       Index Options      NIFTY    24-Sep-2020           Call
# 4       Index Options  BANKNIFTY    24-Sep-2020           Call
# 5       Index Options  BANKNIFTY    24-Sep-2020            Put
# 6       Index Options      NIFTY    24-Sep-2020           Call
# 7       Index Options  BANKNIFTY    24-Sep-2020            Put
# 8       Index Options  BANKNIFTY    24-Sep-2020           Call
# 9       Index Options      NIFTY    24-Sep-2020            Put
# 10      Index Options      NIFTY    24-Sep-2020           Call
# 11      Index Futures  BANKNIFTY    24-Sep-2020              -
# 12      Index Options      NIFTY    24-Sep-2020           Call
# 13      Index Options  BANKNIFTY    24-Sep-2020            Put
# 14      Index Options      NIFTY    24-Sep-2020            Put
# 15      Index Options      NIFTY    24-Sep-2020            Put
# 16      Index Options      NIFTY    24-Sep-2020            Put
# 17      Index Options      NIFTY    24-Sep-2020           Call
# 18      Index Options      NIFTY    24-Sep-2020           Call
# 19      Index Options      NIFTY    24-Sep-2020           Call
#
#    STRIKE PRICE \n LAST PRICE \n  CHNG \n  %CHNG \n  VOLUME \n(Contracts)  \
# 0        22,000.00        280.00    52.05     22.83                651793
# 1        22,500.00        187.00  -153.95    -45.15                637454
# 2        11,500.00         84.50   -18.65    -18.08                546797
# 3        11,600.00         53.40   -21.55    -28.75                530700
# 4        23,000.00         70.05   -92.20    -56.83                504184
# 5        21,500.00        126.00    19.10     17.87                442543
# 6        11,700.00         22.65   -16.45    -42.07                379409
# 7        21,000.00         53.10     3.30      6.63                349623
# 8        22,400.00        215.05  -175.35    -44.92                340854
# 9        11,400.00         53.00   -15.60    -22.74                332328
# 10       11,500.00        104.00   -22.30    -17.66                302169
# 11               -     22,124.00  -267.95     -1.20                285900
# 12       11,800.00          7.60    -9.90    -56.57                280794
# 13       22,300.00        435.95    89.10     25.69                279614
# 14       11,600.00        133.95   -17.60    -11.61                265223
# 15       11,300.00         34.25   -10.40    -23.29                226291
# 16       11,550.00        105.75   -19.50    -15.57                190707
# 17       11,550.00         75.85   -23.00    -23.27                185335
# 18       11,650.00         35.50   -19.70    -35.69                178845
# 19       11,900.00          3.65    -3.90    -51.66                173407
#
#                 VALUE   OPEN INTEREST \n UNDERLYING VALUE \n
# 0     4,410,683,231.00             24410           22,031.05
# 1     4,170,702,158.50             43538           22,031.05
# 2     3,458,764,423.50             45108           11,504.95
# 3     2,874,138,525.00             45967           11,504.95
# 4     1,434,403,480.00             42860           22,031.05
# 5     1,667,391,388.25             22824           22,031.05
# 6       976,598,766.00             35358           11,504.95
# 7       663,584,454.00             29142           22,031.05
# 8     2,649,287,715.00             14388           22,031.05
# 9     1,393,783,632.00             32879           11,504.95
# 10    2,754,194,892.75             43292           11,504.95
# 11  158,884,422,075.00             61813           22,031.05
# 12      281,776,779.00             44338           11,504.95
# 13    2,482,552,899.00              5107           22,031.05
# 14    2,496,809,322.00             16685           11,504.95
# 15      609,288,517.50             30525           11,504.95
# 16    1,438,598,254.50              7778           11,504.95
# 17    1,334,551,001.25              9965           11,504.95
# 18      675,765,832.50             13352           11,504.95
# 19       68,799,227.25             27298           11,504.95
